# %% [markdown]
# <a href="https://colab.research.google.com/github/johnboscoimmanuel/PRACTICE/blob/main/NBA_Games_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('/content/games.csv')
df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2022-03-12  22101005            Final    1610612748       1610612750
# 1    2022-03-12  22101006            Final    1610612741       1610612739
# 2    2022-03-12  22101007            Final    1610612759       1610612754
# 3    2022-03-12  22101008            Final    1610612744       1610612749
# 4    2022-03-12  22101009            Final    1610612743       1610612761
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2021    1610612748     104.0        0.398        0.760  ...      23.0
# 1    2021    1610612741     101.0        0.443        0.933  ...      20.0
# 2    2021    1610612759     108.0        0.412        0.813  ...      28.0
# 3    2021    1610612744     122.0        0.484        0.933  ...      33.0
# 4    2021    1610612743     115.0        0.551        0.750  ...      32.0
#
# ...

# %%
df.tail()
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 25791    2014-10-06  11400007            Final    1610612737       1610612740
# 25792    2014-10-06  11400004            Final    1610612741       1610612764
# 25793    2014-10-06  11400005            Final    1610612747       1610612743
# 25794    2014-10-05  11400002            Final    1610612761       1610612758
# 25795    2014-10-04  11400001            Final    1610612748       1610612740
#
#        SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  \
# 25791    2014    1610612737      93.0        0.419        0.821  ...
# 25792    2014    1610612741      81.0        0.338        0.719  ...
# 25793    2014    1610612747      98.0        0.448        0.682  ...
# 25794    2014    1610612761      99.0        0.440        0.771  ...
# 25795    2014    1610612748      86.0        0.431        0.679  ...
#
#        AST_home  REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  \
# ...

# %%
df.shape
# Out:
# (25796, 21)

# %%
df.isna().sum()
# Out:
# GAME_DATE_EST        0
# GAME_ID              0
# GAME_STATUS_TEXT     0
# HOME_TEAM_ID         0
# VISITOR_TEAM_ID      0
# SEASON               0
# TEAM_ID_home         0
# PTS_home            99
# FG_PCT_home         99
# FT_PCT_home         99
# FG3_PCT_home        99
# AST_home            99
# REB_home            99
# TEAM_ID_away         0
# PTS_away            99
# FG_PCT_away         99
# FT_PCT_away         99
# FG3_PCT_away        99
# AST_away            99
# REB_away            99
# HOME_TEAM_WINS       0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (25697, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25697 entries, 0 to 25795
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GAME_DATE_EST     25697 non-null  object
#  1   GAME_ID           25697 non-null  int64
#  2   GAME_STATUS_TEXT  25697 non-null  object
#  3   HOME_TEAM_ID      25697 non-null  int64
#  4   VISITOR_TEAM_ID   25697 non-null  int64
#  5   SEASON            25697 non-null  int64
#  6   TEAM_ID_home      25697 non-null  int64
#  7   PTS_home          25697 non-null  float64
#  8   FG_PCT_home       25697 non-null  float64
#  9   FT_PCT_home       25697 non-null  float64
#  10  FG3_PCT_home      25697 non-null  float64
#  11  AST_home          25697 non-null  float64
#  12  REB_home          25697 non-null  float64
#  13  TEAM_ID_away      25697 non-null  int64
#  14  PTS_away          25697 non-null  float64
#  15  FG_PCT_away       25697 non-null  float64
# ...

# %%
df.describe()
# Out:
#             GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID        SEASON  \
# count  2.569700e+04  2.569700e+04     2.569700e+04  25697.000000
# mean   2.173597e+07  1.610613e+09     1.610613e+09   2011.832237
# std    5.460853e+06  8.641473e+00     8.655103e+00      5.380624
# min    1.030000e+07  1.610613e+09     1.610613e+09   2003.000000
# 25%    2.060117e+07  1.610613e+09     1.610613e+09   2007.000000
# 50%    2.120045e+07  1.610613e+09     1.610613e+09   2012.000000
# 75%    2.170072e+07  1.610613e+09     1.610613e+09   2016.000000
# max    5.200021e+07  1.610613e+09     1.610613e+09   2021.000000
#
#        TEAM_ID_home      PTS_home   FG_PCT_home   FT_PCT_home  FG3_PCT_home  \
# count  2.569700e+04  25697.000000  25697.000000  25697.000000  25697.000000
# mean   1.610613e+09    103.106044      0.460313      0.759705      0.355896
# std    8.641473e+00     13.174726      0.056629      0.100692      0.111940
# ...

# %%
df.columns
# Out:
# Index(['GAME_DATE_EST', 'GAME_ID', 'GAME_STATUS_TEXT', 'HOME_TEAM_ID',
#        'VISITOR_TEAM_ID', 'SEASON', 'TEAM_ID_home', 'PTS_home', 'FG_PCT_home',
#        'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home', 'TEAM_ID_away',
#        'PTS_away', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away',
#        'REB_away', 'HOME_TEAM_WINS'],
#       dtype='object')

# %%
corr=df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True,square=True,cmap='PuBu',fmt=".1g")
plt.title('correlation for dataset')
plt.show()

# %%
df.dtypes
# Out:
# GAME_DATE_EST        object
# GAME_ID               int64
# GAME_STATUS_TEXT     object
# HOME_TEAM_ID          int64
# VISITOR_TEAM_ID       int64
# SEASON                int64
# TEAM_ID_home          int64
# PTS_home            float64
# FG_PCT_home         float64
# FT_PCT_home         float64
# FG3_PCT_home        float64
# AST_home            float64
# REB_home            float64
# TEAM_ID_away          int64
# PTS_away            float64
# FG_PCT_away         float64
# FT_PCT_away         float64
# FG3_PCT_away        float64
# AST_away            float64
# REB_away            float64
# HOME_TEAM_WINS        int64
# dtype: object

# %%
# #plt.figure(figsize=(15,10))
# sns.pairplot(df,hue='HOME_TEAM_WINS')
# plt.title('pairplot for dataset')
# plt.show()

# %%
df_ids=df[['GAME_ID','GAME_DATE_EST','HOME_TEAM_ID','VISITOR_TEAM_ID','TEAM_ID_home','TEAM_ID_away']]
df_ids.head()
# Out:
#     GAME_ID GAME_DATE_EST  HOME_TEAM_ID  VISITOR_TEAM_ID  TEAM_ID_home  \
# 0  22101005    2022-03-12    1610612748       1610612750    1610612748
# 1  22101006    2022-03-12    1610612741       1610612739    1610612741
# 2  22101007    2022-03-12    1610612759       1610612754    1610612759
# 3  22101008    2022-03-12    1610612744       1610612749    1610612744
# 4  22101009    2022-03-12    1610612743       1610612761    1610612743
#
#    TEAM_ID_away
# 0    1610612750
# 1    1610612739
# 2    1610612754
# 3    1610612749
# 4    1610612761

# %%
sns.pairplot(df_ids)
plt.show()

# %%
sns.heatmap(df_ids.corr(),annot=True,cmap='PuBu')
plt.show()

# %%
df.drop(df_ids,axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['GAME_STATUS_TEXT', 'SEASON', 'PTS_home', 'FG_PCT_home', 'FT_PCT_home',
#        'FG3_PCT_home', 'AST_home', 'REB_home', 'PTS_away', 'FG_PCT_away',
#        'FT_PCT_away', 'FG3_PCT_away', 'AST_away', 'REB_away',
#        'HOME_TEAM_WINS'],
#       dtype='object')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_theme()
plt.figure(figsize=(18,8))
sns.countplot(df['SEASON'],data=df,order=df['SEASON'].value_counts().index)
plt.title('SEASON OF NBA')
plt.show()

# %%
fig,ax=plt.subplots(2,2,figsize=(12,8))
sns.distplot(df.PTS_home,color='r',ax=ax[0,0])
sns.histplot(df.FG_PCT_home,color='g',ax=ax[0,1])
sns.distplot(df.FG3_PCT_home,color='b',ax=ax[1,0])
sns.distplot(df.AST_home,color='b',ax=ax[1,1])
plt.show()

# %%
df.REB_home.hist()
plt.title('FG_PCT_home Teams')
plt.show()

# %%
sns.distplot(df['FT_PCT_home'],color='g')
plt.title('Points of Home Teams')
plt.show()

# %%
fig,axes=plt.subplots(2,3,figsize=(12,8))
fig.suptitle('AWay Subplots ')
sns.distplot(df.PTS_away,ax=axes[0,0],bins=20,)
sns.distplot(df.FG_PCT_away,ax=axes[0,1],bins=20)
sns.distplot(df.FT_PCT_away,ax=axes[0,2],bins=20)
sns.distplot(df.FG3_PCT_away,ax=axes[1,0],bins=20)
sns.distplot(df.AST_away,ax=axes[1,1],bins=20)
sns.distplot(df.REB_away,ax=axes[1,2],bins=20)
plt.show()

# %%
df['HOME_TEAM_WINS'].value_counts()
# Out:
# 1    15155
# 0    10542
# Name: HOME_TEAM_WINS, dtype: int64

# %%
sns.countplot(df['HOME_TEAM_WINS'],data=df)
plt.title('HOME_TEAM_WINS')
plt.show()

# %%
df.columns
# Out:
# Index(['GAME_STATUS_TEXT', 'SEASON', 'PTS_home', 'FG_PCT_home', 'FT_PCT_home',
#        'FG3_PCT_home', 'AST_home', 'REB_home', 'PTS_away', 'FG_PCT_away',
#        'FT_PCT_away', 'FG3_PCT_away', 'AST_away', 'REB_away',
#        'HOME_TEAM_WINS'],
#       dtype='object')

# %%
df.drop(labels='GAME_STATUS_TEXT',axis=1,inplace=True)

# %%
sns.scatterplot(df['PTS_home'],df['PTS_away'],hue='HOME_TEAM_WINS',data=df)
plt.title('home and away for relation')
plt.show()

# %%
sns.scatterplot(df['FG_PCT_home'],df['FG_PCT_away'],hue='HOME_TEAM_WINS',data=df)
plt.title('FG_PCT_home and FG_PCT_away')
plt.show()

# %%
sns.jointplot(df['FT_PCT_home'],df['FT_PCT_away'],data=df,hue_order='HOME_TEAM_WINS')
plt.title('FT_PCT_home and FT_PCT_away',pad=3,loc='right')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(df['FG3_PCT_home'],data=df)
plt.show()

# %%
sns.scatterplot(df.AST_home,df.AST_away)
sns.lineplot(df.REB_home,df.REB_away)
plt.show()

# %%
col=df[['SEASON', 'PTS_home', 'FG_PCT_home', 'FT_PCT_home',
       'FG3_PCT_home', 'AST_home', 'REB_home', 'PTS_away', 'FG_PCT_away',
       'FT_PCT_away', 'FG3_PCT_away', 'AST_away', 'REB_away']]
col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25697 entries, 0 to 25795
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SEASON        25697 non-null  int64
#  1   PTS_home      25697 non-null  float64
#  2   FG_PCT_home   25697 non-null  float64
#  3   FT_PCT_home   25697 non-null  float64
#  4   FG3_PCT_home  25697 non-null  float64
#  5   AST_home      25697 non-null  float64
#  6   REB_home      25697 non-null  float64
#  7   PTS_away      25697 non-null  float64
#  8   FG_PCT_away   25697 non-null  float64
#  9   FT_PCT_away   25697 non-null  float64
#  10  FG3_PCT_away  25697 non-null  float64
#  11  AST_away      25697 non-null  float64
#  12  REB_away      25697 non-null  float64
# dtypes: float64(12), int64(1)
# memory usage: 3.8 MB

# %%
for i in col:
  sns.boxplot(df[i],data=df)
  plt.title('find outliers')
  plt.show()

# %%
q1=df['PTS_home'].quantile(0.25)
q3=df['PTS_home'].quantile(0.75)
IQR=q3-q1
low_limit=q1-1.5*IQR
up_limit=q3+1.5*IQR
df[(df.PTS_home<low_limit) | (df.PTS_home>up_limit)]
df=df[(df.PTS_home<up_limit) & (df.PTS_home>low_limit)]

# %%
q1=df['FG_PCT_home'].quantile(0.25)
q3=df['FG_PCT_home'].quantile(0.75)
IQR=q3-q1
low_limit=q1-1.5*IQR
up_limit=q3+1.5*IQR
df[(df.FG_PCT_home<low_limit) | (df.FG_PCT_home>up_limit)]
df=df[(df.FG_PCT_home<up_limit) & (df.FG_PCT_home>low_limit)]

# %%
q1=df['FT_PCT_home'].quantile(0.25)
q3=df['FT_PCT_home'].quantile(0.75)
IQR=q3-q1
low_limit=q1-1.5*IQR
up_limit=q3+1.5*IQR
df[(df.FT_PCT_home<low_limit) | (df.FT_PCT_home>up_limit)]
df=df[(df.FT_PCT_home<up_limit) & (df.FT_PCT_home>low_limit)]

# %%
q1=df['AST_home'].quantile(0.25)
q3=df['AST_home'].quantile(0.75)
IQR=q3-q1
low_limit=q1-1.5*IQR
up_limit=q3+1.5*IQR
df[(df.AST_home<low_limit) | (df.AST_home>up_limit)]
df=df[(df.AST_home<up_limit) & (df.AST_home>low_limit)]

# %%
q1=df['FG3_PCT_home'].quantile(0.25)
q3=df['FG3_PCT_home'].quantile(0.75)
IQR=q3-q1
low_limit=q1-1.5*IQR
up_limit=q3+1.5*IQR
df[(df.FG3_PCT_home<low_limit) | (df.FG3_PCT_home>up_limit)]
df=df[(df.FG3_PCT_home<up_limit) & (df.FG3_PCT_home>low_limit)]

# %%
q1=df['REB_home'].quantile(0.25)
q3=df['REB_home'].quantile(0.75)
IQR=q3-q1
low_limit=q1-1.5*IQR
up_limit=q3+1.5*IQR
df[(df.REB_home<low_limit) | (df.REB_home>up_limit)]
df=df[(df.REB_home<up_limit) & (df.REB_home>low_limit)]

# %%
df.shape
# Out:
# (24468, 14)

# %%
q1=df['PTS_away'].quantile(0.25)
q3=df['PTS_away'].quantile(0.75)
IQR=q3-q1
low_limit=q1-1.5*IQR
up_limit=q3+1.5*IQR
df[(df.PTS_away<low_limit) | (df.PTS_away>up_limit)]
df=df[(df.PTS_away<up_limit) & (df.PTS_away>low_limit)]

# %%
q1=df['FG_PCT_away'].quantile(0.25)
q3=df['FG_PCT_away'].quantile(0.75)
IQR=q3-q1
low_limit=q1-1.5*IQR
up_limit=q3+1.5*IQR
df[(df.FG_PCT_away<low_limit) | (df.FG_PCT_away>up_limit)]
df=df[(df.FG_PCT_away<up_limit) & (df.FG_PCT_away>low_limit)]

# %%
q1=df['FT_PCT_away'].quantile(0.25)
q3=df['FT_PCT_away'].quantile(0.75)
IQR=q3-q1
low_limit=q1-1.5*IQR
up_limit=q3+1.5*IQR
df[(df.FT_PCT_away<low_limit) | (df.FT_PCT_away>up_limit)]
df=df[(df.FT_PCT_away<up_limit) & (df.FT_PCT_away>low_limit)]

# %%
q1=df['FG3_PCT_away'].quantile(0.25)
q3=df['FG3_PCT_away'].quantile(0.75)
IQR=q3-q1
low_limit=q1-1.5*IQR
up_limit=q3+1.5*IQR
df[(df.FG3_PCT_away<low_limit) | (df.FG3_PCT_away>up_limit)]
df=df[(df.FG3_PCT_away<up_limit) & (df.FG3_PCT_away>low_limit)]

# %%
# q1=df['AST_away'].quantile(0.40)
# q3=df['AST_away'].quantile(0.75)
# IQR=q3-q1
# low_limit=q1-1.5*IQR
# up_limit=q3+1.5*IQR
# df[(df.AST_away<low_limit) | (df.AST_away>up_limit)]
# df[(df.AST_away<up_limit) & (df.AST_away>low_limit)]

# %%
df.shape
# Out:
# (23633, 14)

# %%
# q1=df['REB_away'].quantile(0.25)
# q3=df['REB_away'].quantile(0.75)
# IQR=q3-q1
# low_limit=q1-1.5*IQR
# up_limit=q3+1.5*IQR
# df[(df.REB_away<low_limit) | (df.REB_away>up_limit)]
# df[(df.REB_away<up_limit) & (df.REB_away>low_limit)]

# %%
fig,ax=plt.subplots(nrows=4,ncols=3,figsize=(10,8))
sns.boxplot(df['PTS_home'],ax=ax[0,0])
sns.boxplot(df['FG_PCT_home'],ax=ax[0,1])
sns.boxplot(df['FT_PCT_home'],ax=ax[0,2])
sns.boxplot(df['FG3_PCT_home'],ax=ax[1,0])
sns.boxplot(df['AST_home'],ax=ax[1,1])
sns.boxplot(df['REB_home'],ax=ax[1,2])
sns.boxplot(df['PTS_away'],ax=ax[2,0])
sns.boxplot(df['FG_PCT_away'],ax=ax[2,1])
sns.boxplot(df['FT_PCT_away'],ax=ax[2,2])
sns.boxplot(df['FG3_PCT_away'],ax=ax[3,0])
sns.boxplot(df['AST_away'],ax=ax[3,1])
sns.boxplot(df['REB_away'],ax=ax[3,2])
plt.show()

# %%
df.columns
# Out:
# Index(['SEASON', 'PTS_home', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home',
#        'AST_home', 'REB_home', 'PTS_away', 'FG_PCT_away', 'FT_PCT_away',
#        'FG3_PCT_away', 'AST_away', 'REB_away', 'HOME_TEAM_WINS'],
#       dtype='object')

# %%
x=df.drop(labels='HOME_TEAM_WINS',axis=1)

y=df['HOME_TEAM_WINS'].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score,roc_auc_score,confusion_matrix,classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=24)

scaler=MinMaxScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

model=LogisticRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
print('confusion_matrix  \n',confusion_matrix(y_test,y_pred))
print('accuracy_score  \n',accuracy_score(y_test,y_pred))
print('roc_auc_score \n',roc_auc_score(y_test,y_pred))
# Out:
# confusion_matrix
#  [[1934   31]
#  [  17 2745]]
# accuracy_score
#  0.9898455680135393
# roc_auc_score
#  0.9890344792006383

# %%
print('classification_report \n',classification_report(y_test,y_pred))
# Out:
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      1965
#            1       0.99      0.99      0.99      2762
#
#     accuracy                           0.99      4727
#    macro avg       0.99      0.99      0.99      4727
# weighted avg       0.99      0.99      0.99      4727
