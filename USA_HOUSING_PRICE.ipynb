# %% [markdown]
# <a href="https://colab.research.google.com/github/johnboscoimmanuel/PRACTICE/blob/main/USA_HOUSING_PRICE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/USA_Housing.csv')
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df.shape
# Out:
# (5000, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df.isna().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(8,7))
sns.heatmap(df.corr(),annot=True,cmap='PuBu',fmt='.2g',cbar=True,linecolor='green')
plt.title('Correlation of the Dataset')
plt.show()

# %%
df.drop(labels='Address',axis=1,inplace=True)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(df['Avg. Area Income'],color='c')
plt.title('Distribution of Avg. Area Income ')
plt.show()

# %%
sns.distplot(df['Avg. Area House Age'],color='pink')
plt.title('Distribution of Avg. Area House Age ')
plt.show()

# %%
plt.hist(df['Avg. Area Number of Rooms'])
plt.title('Distribution of Avg. Area Number of Rooms ')
plt.show()

# %%
plt.figure(figsize=(5,8))
sns.distplot(df['Avg. Area Number of Bedrooms'],label=True)
plt.title('Distribution of Avg. Area Number of Bedrooms ')
plt.show()

# %%
sns.histplot(df['Area Population'],kde=True,cbar=True)
plt.title('DISTRIBUSION FOR Area Population ')
plt.show()

# %%
sns.set()
sns.distplot(df['Price'],kde=True,bins=20,color='green')
plt.title('DISTRIBUSION FOR PRICE ')
plt.show()

# %%
sns.scatterplot(df['Avg. Area Income'],df['Price'],data=df)
plt.title('Relation between Income and Price')
plt.show()

# %%
sns.jointplot(df['Avg. Area House Age'],df['Price'],data=df,color='green')
plt.title(' House Age and Price',pad=15)
plt.show()

# %%
sns.scatterplot(df['Avg. Area Number of Rooms'],df['Price'],data=df,color='yellow')
plt.title('Number of Rooms and Price')
plt.show()

# %%
plt.figure(figsize=(15,15))
df.plot(kind='hist')
plt.show()

# %%
sns.regplot(df['Avg. Area Number of Bedrooms'],df['Price'],data=df)
plt.title('Number of Bedrooms and Price')
plt.show()

# %%
sns.scatterplot(df['Area Population'],df['Price'])
plt.title('Area Population and price')
plt.show()

# %%
sns.pairplot(df,kind='scatter')
plt.show()

# %%
fig,axes=plt.subplots(ncols=2,nrows=3,figsize=(10,15))
sns.boxplot(df['Avg. Area Income'],ax=axes[0,0],color='r')
sns.boxplot(df['Avg. Area House Age'],ax=axes[0,1],color='c')
sns.boxplot(df['Avg. Area Number of Rooms'],ax=axes[1,0],color='blue')
sns.boxplot(df['Avg. Area Number of Bedrooms'],ax=axes[1,1],color='red')
sns.boxplot(df['Area Population'],ax=axes[2,0],color='pink')
sns.boxplot(df['Price'],ax=axes[2,1],color='green')
plt.suptitle("Outliers Detection")
plt.show()

# %%
max=df.Price.quantile(0.95)
min=df.Price.quantile(0.05)
df[df.Price>max],df[df.Price<min]
df=df[(df.Price<max)& (df.Price>min)]

# %%
max=df['Avg. Area Income'].quantile(0.95)
min=df['Avg. Area Income'].quantile(0.05)
df[df['Avg. Area Income']>max],df[df['Avg. Area Income']<min]
df=df[(df['Avg. Area Income']<max)& (df['Avg. Area Income']>min)]

# %%
max=df['Avg. Area House Age'].quantile(0.95)
min=df['Avg. Area House Age'].quantile(0.05)
df[df['Avg. Area House Age']>max],df[df['Avg. Area House Age']<min]
df=df[(df['Avg. Area House Age']<max)& (df['Avg. Area House Age']>min)]

# %%
max=df['Avg. Area Number of Rooms'].quantile(0.95)
min=df['Avg. Area Number of Rooms'].quantile(0.05)
df[df['Avg. Area Number of Rooms']>max],df[df['Avg. Area Number of Rooms']<min]
df=df[(df['Avg. Area Number of Rooms']<max)& (df['Avg. Area Number of Rooms']>min)]

# %%
max=df['Area Population'].quantile(0.95)
min=df['Area Population'].quantile(0.05)
df[df['Area Population']>max],df[df['Area Population']<min]
df=df[(df['Area Population']<max)& (df['Area Population']>min)]

# %%
df.shape
# Out:
# (2950, 6)

# %%
fig,axes=plt.subplots(ncols=2,nrows=3,figsize=(10,15))
sns.boxplot(df['Avg. Area Income'],ax=axes[0,0],color='r')
sns.boxplot(df['Avg. Area House Age'],ax=axes[0,1],color='c')
sns.boxplot(df['Avg. Area Number of Rooms'],ax=axes[1,0],color='blue')
sns.boxplot(df['Avg. Area Number of Bedrooms'],ax=axes[1,1],color='red')
sns.boxplot(df['Area Population'],ax=axes[2,0],color='pink')
sns.boxplot(df['Price'],ax=axes[2,1],color='green')
plt.suptitle("Outliers Remove")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price'],
#       dtype='object')

# %%
x=df.drop(labels='Price',axis=1)
print(x.columns)
y=df['Price']
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population'],
#       dtype='object')

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=10)

print(x_train.shape,x_test.shape)
# Out:
# (2212, 5) (738, 5)

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=100).fit(x_train,y_train)
forest_pred=rf.predict(x_test)

# %%
print('mean_squared_error: \n',mean_squared_error(y_test,forest_pred))
print('r2_score : \n',round(r2_score(y_test,forest_pred),2))
# Out:
# mean_squared_error:
#  12228246724.46156
# r2_score :
#  0.81

# %%
lr=LinearRegression().fit(x_train,y_train)
linear_pred=lr.predict(x_test)

# %%
print('mean_squared_error: \n',mean_squared_error(y_test,linear_pred))
print('r2_score : \n',round(r2_score(y_test,linear_pred),2))
# Out:
# mean_squared_error:
#  9692789549.039238
# r2_score :
#  0.85

# %%
lr.coef_
# Out:
# array([2.09056716e+01, 1.62869123e+05, 1.16515660e+05, 1.97627371e+03,
#        1.46254535e+01])

# %%
lr.intercept_
# Out:
# -2526936.677312248

# %%
input_data=(78394.33927753085,6.9897797477182815,6.620477995185026,2.42,36516.358972493836)

input_data_as_numpy_array=np.asarray(input_data)

reshape_numpy_array=input_data_as_numpy_array.reshape(1,-1)

prediction=lr.predict(reshape_numpy_array)

print(prediction)
# Out:
# [1557092.48289758]

# %%
print(f'Actual Price : {1573936.5644777215}')
print('----------------------------------')
print(f'Predicted Price : {prediction}')
# Out:
# Actual Price : 1573936.5644777215
# ----------------------------------
# Predicted Price : [1557092.48289758]

# %%
actual=1573936.5644777215
diffrent_price=actual - prediction

print(f'Diffrent_ Price of the model : {diffrent_price}')
# Out:
# Diffrent_ Price of the model : [16844.08158015]
